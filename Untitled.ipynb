# %%
import pandas as pd
import numpy as np
import random
import datetime

# %%
olist_customer = pd.read_csv('olist_customers_dataset.csv')
olist_geolocation = pd.read_csv('olist_geolocation_dataset.csv')
olist_orders = pd.read_csv('olist_orders_dataset.csv')
olist_order_items = pd.read_csv('olist_order_items_dataset.csv')
olist_order_payments = pd.read_csv('olist_order_payments_dataset.csv')
olist_products = pd.read_csv('olist_products_dataset.csv')
olist_sellers = pd.read_csv('olist_sellers_dataset.csv')

# %% [markdown]
# ![Screenshot%202023-04-04%20at%2012.22.02.png](attachment:Screenshot%202023-04-04%20at%2012.22.02.png)

# %%
customer_df = pd.read_csv('customer_df.csv')
sellers_df = pd.read_csv('sellers_df.csv')
products_df = pd.read_csv('products_df.csv')
order_final = pd.read_csv('order_final.csv')

# %%
df1 = pd.read_csv('final_df_2021_1_2.csv')
df2 = pd.read_csv('final_df_2021_3_4.csv')
df3 = pd.read_csv('final_df_2021_5_6.csv')
df4 = pd.read_csv('final_df_2021_7_8.csv')
df5 = pd.read_csv('final_df_2021_9_10.csv')
df6 = pd.read_csv('final_df_2021_11_12.csv')
df7 = pd.read_csv('final_df_2022_1_2.csv')
df8 = pd.read_csv('final_df_2022_3_4.csv')
df9 = pd.read_csv('final_df_2022_5_6.csv')
df10 = pd.read_csv('final_df_2022_7_8.csv')
df11 = pd.read_csv('final_df_2022_9_10.csv')
df12 = pd.read_csv('final_df_2022_11_12.csv')

# %%
orders_df = pd.concat([df1, df2, df3, df4, df5, df6, df7,df8,df9,df10,df11,df12]).reset_index(drop=True)

# %%
orders_df.head()
# Out:
#                              order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af711  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e215027345111  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d11  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a11  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f815911  8ab97904e6daea8866dbdbc4fb7aad2c
#
#    order_item_id                        product_id  \
# 0              1  87285b34884572647811a353c7ac498a
# 1              1  595fac2a385ac33a80bd5114aec74eb8
# 2              1  aa4383b373c6aca5d8797843e5594415
# 3              1  d0b61bfb1de832b15ba9d266ca96e5b0
# 4              1  65266b2da20d04dbe00c5c2d3bb7859e
#
#                           seller_id   price  freight_value  \
# 0  3504c0cb71d7fa48d967e0e4c94d59d9   29.99           8.72
# 1  289cdb325fb7e7f891c38608bf9e0962  118.70          22.76
# ...

# %%
orders_df.to_csv('orders_df.csv', index=False)
